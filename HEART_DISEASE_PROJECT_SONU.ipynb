# %% [markdown]
# <a href="https://colab.research.google.com/github/sonupp13/MY-PROJECTS-IN-MACHINE-LEARNING/blob/main/HEART_DISEASE_PROJECT_SONU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing data

# %%
data= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Heart_Disease_Prediction.csv")
data
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# checking for null values

# %%
data.isna().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %% [markdown]
# droping null values if any

# %%
data.dropna(inplace=True)

# %% [markdown]
# information of data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %% [markdown]
# describing data

# %%
data.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
data.value_counts()
# Out:
# Age  Sex  Chest pain type  BP   Cholesterol  FBS over 120  EKG results  Max HR  Exercise angina  ST depression  Slope of ST  Number of vessels fluro  Thallium  Heart Disease
# 29   1    2                130  204          0             2            202     0                0.0            1            0                        3         Absence          1
# 59   1    4                170  326          0             2            140     1                3.4            3            0                        7         Presence         1
# 58   1    4                128  259          0             2            130     1                3.0            2            2                        7         Presence         1
#                            146  218          0             0            105     0                2.0            2            1                        7         Presence         1
# ...

# %%
data['Heart Disease'].value_counts()
# Out:
# Absence     150
# Presence    120
# Name: Heart Disease, dtype: int64

# %% [markdown]
# # VISUALISING THE FEATURES

# %%
data['Age'].hist(color='yellow')
data['ST depression'].hist(color='blue')
# Out:
# <Axes: >

# %%
data['Age'].hist(color='yellow')
data['BP'].hist(color='blue')
# Out:
# <Axes: >

# %%
data.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(),annot= True)
# Out:
# <ipython-input-15-f3f7eedaa55e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
# <ipython-input-15-f3f7eedaa55e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot= True)
# <Axes: >

# %%
sns.distplot(data['Age'])
# Out:
# <ipython-input-18-ec135ce2bd5e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Sex',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Sex',y='Age',data=data)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='Sex',y='Age',data=data,hue='Heart Disease')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(15, 10))
sns.violinplot(x='Age',y='Heart Disease',data=data,palette='rainbow')
# Out:
# <ipython-input-24-0c7756e14b91>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Age',y='Heart Disease',data=data,palette='rainbow')
# <Axes: xlabel='Age', ylabel='Heart Disease'>

# %%
s=data["Sex"].value_counts()
s
# Out:
# 1    183
# 0     87
# Name: Sex, dtype: int64

# %%
s=data["Sex"].value_counts()
plt.bar(s.index,s.values)
plt.xlabel('sex')
plt.show()

# %%
age=data['Age'].dropna()
plt.hist(age,bins=20, color='m', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
h=data['Heart Disease'].value_counts()
h
# Out:
# Absence     150
# Presence    120
# Name: Heart Disease, dtype: int64

# %%
sns.countplot(h, edgecolor='black')
plt.xlabel('heart disease')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Output is Categorical, So we need to convert to numeric
#
# ''' LabelEncoder from the sklearn.preprocessing module to transform the categorical column 'Species' into numerical values.
#
# The main purpose of this process is to convert categorical data into a format that machine learning models can understand and use for analysis or training

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Heart Disease']=le.fit_transform(data['Heart Disease'])
data
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# # Feature scaling using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))
data_scaled= sc.fit_transform(data)

# %%
data_scaled= pd.DataFrame(data_scaled)
data_scaled
# Out:
#            0    1         2         3         4    5    6         7    8   \
# 0    0.854167  1.0  1.000000  0.339623  0.447489  0.0  1.0  0.290076  0.0
# 1    0.791667  0.0  0.666667  0.198113  1.000000  0.0  1.0  0.679389  0.0
# 2    0.583333  1.0  0.333333  0.283019  0.308219  0.0  0.0  0.534351  0.0
# 3    0.729167  1.0  1.000000  0.320755  0.312785  0.0  0.0  0.259542  1.0
# 4    0.937500  0.0  0.333333  0.245283  0.326484  0.0  1.0  0.381679  1.0
# ..        ...  ...       ...       ...       ...  ...  ...       ...  ...
# 265  0.479167  1.0  0.666667  0.735849  0.166667  1.0  0.0  0.694656  0.0
# 266  0.312500  1.0  0.333333  0.245283  0.312785  0.0  0.0  0.778626  0.0
# 267  0.562500  0.0  0.333333  0.433962  0.383562  0.0  1.0  0.625954  0.0
# 268  0.583333  1.0  1.000000  0.433962  0.150685  0.0  0.0  0.587786  0.0
# 269  0.791667  1.0  1.000000  0.622642  0.365297  0.0  1.0  0.282443  1.0
#
#            9    10        11    12   13
# ...

# %%
data_scaled.describe()
# Out:
#                0           1           2           3           4           5   \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.529861    0.677778    0.724691    0.352306    0.282327    0.148148
# std      0.189772    0.468195    0.316697    0.168506    0.118005    0.355906
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.395833    0.000000    0.666667    0.245283    0.198630    0.000000
# 50%      0.541667    1.000000    0.666667    0.339623    0.271689    0.000000
# 75%      0.666667    1.000000    1.000000    0.433962    0.351598    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9           10          11  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.511111    0.600594    0.329630    0.169355    0.292593    0.223457
# ...

# %% [markdown]
# importing modules for model builiding

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# # feature selection
#
# in correlation heat map we can see age , bp,cholestrol , sex,chest pain type,exercise angina, st depression , slope of st , number of vessels fluro , thallium etc affect the outcome the most
# ie, more positively correlated features are age , bp ,cholestrol ,sex,chest pain type,exercise angina, st depression , slope of st , number of vessels fluro , thallium .

# %%
x = data_scaled.iloc[:, [0,1,2,3,4,8,9,10,11,12]].values
y = data_scaled.iloc[:, [13]].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
# Checking dimensions
print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("Y_train shape:", y_train.shape)
print("Y_test shape:", y_test.shape)
# Out:
# X_train shape: (202, 10)
# X_test shape: (68, 10)
# Y_train shape: (202, 1)
# Y_test shape: (68, 1)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred= model.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8382352941176471

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[37,  3],
#        [ 8, 20]])

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,  y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.93      0.87        40
#          1.0       0.87      0.71      0.78        28
#
#     accuracy                           0.84        68
#    macro avg       0.85      0.82      0.83        68
# weighted avg       0.84      0.84      0.84        68

# %% [markdown]
# # MODEL PREDICTION

# %%
data
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
age = float(input("Enter age: "))
sex= float(input("Enter sex: "))
Chest_pain_type = float(input("chest: "))
BP= float(input("bp: "))
cholestrol = float(input("cholestrol: "))
Exercise_angina = float(input("exercise angina: "))
ST_depression = float(input("dipression: "))
Slope_of_ST = float(input("slope of st: "))
Number_of_vessels_fluro = float(input("no. of vessels: "))
Thallium= float(input("Enter thallium : "))
input_data = [[age,sex,Chest_pain_type,BP,cholestrol,Exercise_angina,ST_depression,Slope_of_ST,Number_of_vessels_fluro,Thallium]]
input_data
model.predict(input_data)
# Out:
# Enter age: 70
# Enter sex: 1
# chest: 4
# bp: 130
# cholestrol: 322
# exercise angina: 0
# dipression: 2.4
# slope of st: 2
# no. of vessels: 3
# Enter thallium : 3
# array([1.])

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
model_decision= DecisionTreeClassifier(criterion='entropy',random_state=42)

# %%
model_decision.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_pred= model_decision.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy*100
# Out:
# 80.88235294117648

# %%
f= confusion_matrix(y_test,y_pred)
print(f)
# Out:
# [[37  3]
#  [10 18]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(35,30))
plot_tree(model_decision,filled=True)
plt.show()

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 0)
classifier.fit(x_train , y_train)
# Out:
# <ipython-input-59-37381d6ab117>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(x_train , y_train)
# RandomForestClassifier(criterion='entropy', n_estimators=200, random_state=0)

# %%
Y_Pred = classifier.predict(x_test)

# %%
accuracy=accuracy_score(y_test,Y_Pred)
accuracy*100
# Out:
# 82.35294117647058

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, Y_Pred)
cm
# Out:
# array([[37,  3],
#        [ 9, 19]])

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_predd = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
l = confusion_matrix(y_test, y_predd)
l
# Out:
# array([[34,  6],
#        [ 5, 23]])

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score



accuracy = accuracy_score(y_test, y_predd)
precision = precision_score(y_test, y_predd)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
# Out:
# Accuracy: 0.8382
# Precision: 0.7931

# %%
TP = 34
TN = 23
FP = 6
FN = 5

total_instances = TP + TN + FP + FN


accuracy = (TP + TN) / total_instances
precision = TP / (TP + FP)
recall = TP / (TP + FN)
false_positive_rate = FP / (FP + TN)
false_negative_rate = FN / (FN + TP)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"False Positive Rate: {false_positive_rate:.2f}")
print(f"False Negative Rate: {false_negative_rate:.2f}")
# Out:
# Accuracy: 0.84
# Precision: 0.85
# Recall: 0.87
# False Positive Rate: 0.21
# False Negative Rate: 0.13

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
model=SVC(kernel='linear',random_state=0)
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear', random_state=0)

# %%
y_preddd= model.predict(x_test)

# %%
accuracy_score(y_preddd,y_test)
# Out:
# 0.8529411764705882

# %%
from sklearn.metrics import confusion_matrix
m= confusion_matrix(y_test, y_preddd)
m
# Out:
# array([[35,  5],
#        [ 5, 23]])

# %%
age = float(input("Enter age: "))
sex= float(input("Enter sex: "))
Chest_pain_type = float(input("chest: "))
BP= float(input("bp: "))
cholestrol = float(input("cholestrol: "))
Exercise_angina = float(input("exercise angina: "))
ST_depression = float(input("dipression: "))
Slope_of_ST = float(input("slope of st: "))
Number_of_vessels_fluro = float(input("no. of vessels: "))
Thallium= float(input("Enter thallium : "))
input_data = [[age,sex,Chest_pain_type,BP,cholestrol,Exercise_angina,ST_depression,Slope_of_ST,Number_of_vessels_fluro,Thallium]]
input_data
model.predict(input_data)
# Out:
# Enter age: 70
# Enter sex: 1
# chest: 4
# bp: 130
# cholestrol: 322
# exercise angina: 0
# dipression: 2.4
# slope of st: 2
# no. of vessels: 3
# Enter thallium : 3
# array([1.])

# %% [markdown]
# # CONCLUSION OF HEART DISEASE PREDICTION
# We did data visualization and data analysis of the target variable
#
# THE ACCURACY SCORE WE GOT USING LOGISTIC REGRESSION IS - 83.82%
#
# THE ACCURACY SCORE WE GOT USING DECISION TREE IS - 80.88%
#
# THE ACCURACY SCORE WE GOT USING RANDOM FOREST TREE IS - 82.35%
#
# THE ACCURACY SCORE WE GOT USING KNN IS - 83.82%
#
# THE ACCURACY SCORE WE GOT USING SVM IS - 85.29%
#
# HERE SVM GIVES MORE ACCURACY
