# %% [markdown]
# <a href="https://colab.research.google.com/github/sonupp13/MY-PROJECTS-IN-MACHINE-LEARNING/blob/main/DIABETIS%20PREDICTION%20USING%20KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data_new= data
import numpy as np

# %%
# there are 0 values in the dataset now we are reolacing it with null values (pregnancy is not considered in diabetis)
data[['Glucose','BloodPressure','SkinThickness','Insulin'	,'BMI']]=data_new[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
# Replacing NaN with mean values
data_new['Glucose'].fillna(data_new['Glucose'].mean(),inplace=True)
data_new['BloodPressure'].fillna(data_new['BloodPressure'].mean(),inplace=True)
data_new['BMI'].fillna(data_new['BMI'].mean(),inplace=True)
data_new['Insulin'].fillna(data_new['Insulin'].mean(),inplace=True)
data_new['SkinThickness'].fillna(data_new['SkinThickness'].mean(),inplace=True)

# %%
# Feature scaling using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1)) # already ulla fn ne sc lekk call cheythu and (o ,1 ) means motham values 0 and 1 nte ullil set cheythu to get mean 0 and std 1
data_scaled=sc.fit_transform(data_new) # full data set converted to make mean 0 and s.d 1

# %%
data_scaled= pd.DataFrame(data_scaled)
data_scaled
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.352941  0.670968  0.489796  0.304348  0.170130  0.314928  0.234415
# 1    0.058824  0.264516  0.428571  0.239130  0.170130  0.171779  0.116567
# 2    0.470588  0.896774  0.408163  0.240798  0.170130  0.104294  0.253629
# 3    0.058824  0.290323  0.428571  0.173913  0.096154  0.202454  0.038002
# 4    0.000000  0.600000  0.163265  0.304348  0.185096  0.509202  0.943638
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  0.588235  0.367742  0.530612  0.445652  0.199519  0.300613  0.039710
# 764  0.117647  0.503226  0.469388  0.217391  0.170130  0.380368  0.111870
# 765  0.294118  0.496774  0.489796  0.173913  0.117788  0.163599  0.071307
# 766  0.058824  0.529032  0.367347  0.240798  0.170130  0.243354  0.115713
# 767  0.058824  0.316129  0.469388  0.260870  0.170130  0.249489  0.101196
#
#             7    8
# 0    0.483333  1.0
# 1    0.166667  0.0
# ...

# %%
# Selecting features - [Glucose, Insulin, BMI, Age]
x = data_scaled.iloc[:, [1, 4, 5, 7]].values  # full rows are selectd using ' : ' and [1, 4, 5, 7] these coluns are selected Glucose, Insulin, BMI, Age
y = data_scaled.iloc[:, 8].values # only output colunmn

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
model= KNeighborsClassifier(n_neighbors=25,metric='minkowski',p=2)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[76, 23],
#        [17, 38]])

# %%
from sklearn.metrics import accuracy_score, precision_score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
# Out:
# Accuracy: 0.74
# Precision: 0.62
